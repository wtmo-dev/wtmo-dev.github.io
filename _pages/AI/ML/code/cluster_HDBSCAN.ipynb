# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets as data_maker
import hdbscan

import warnings
warnings.filterwarnings("ignore")

from sklearn.metrics import confusion_matrix, f1_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# %%
data = pd.read_csv("https://raw.githubusercontent.com/GonieAhn/Data-Science-online-course-from-gonie/main/Data%20Store/example_data.csv")

# %%
data.head()
# Out:
#    censor  event  age    wtkg  hemo  homo  drugs  karnof  oprior  z30  ...  \
# 0       0   1090   43  66.679     0     1      0     100       0    1  ...
# 1       1    794   31  73.030     0     1      0     100       0    1  ...
# 2       0    957   41  66.226     0     1      1     100       0    1  ...
# 3       1    188   35  78.019     0     1      0     100       0    1  ...
# 4       1    308   40  83.009     0     1      0     100       0    1  ...
#
#    gender  str2  strat  symptom  cd40  cd420  cd496  r  cd80  cd820
# 0       1     1      3        0   504    353    660  1   870    782
# 1       1     1      3        0   244    225    106  1   708    699
# 2       1     1      3        0   401    366    453  1   889    720
# 3       1     1      3        0   221    132     -1  0   221    759
# 4       1     1      3        1   150     90     20  1  1730   1160
#
# [5 rows x 23 columns]

# %%
Y = data['censor']
X = data.drop(columns=['censor'])

# %%
data.columns
# Out:
# Index(['censor', 'event', 'age', 'wtkg', 'hemo', 'homo', 'drugs', 'karnof',
#        'oprior', 'z30', 'zprior', 'preanti', 'race', 'gender', 'str2', 'strat',
#        'symptom', 'cd40', 'cd420', 'cd496', 'r', 'cd80', 'cd820'],
#       dtype='object')

# %%
data['cd820'].unique()
# Out:
# array([ 782,  699,  720,  759, 1160,  990, 1000, 2265, 1698, 1017,  710,
#        1780,  490, 1220, 1590, 1020,  420,  690,  850,  640, 1034,  590,
#         847, 1191, 1287, 1070, 1143, 1125,  784, 1573,  799, 1415, 1338,
#         440,  943,  967, 1909, 1905, 1282, 1131,  749,  611, 1558, 1488,
#         823,  765,  528,  642, 1170,  545,  816, 1186,  449,  454,  460,
#         786,  678, 1295,  612,  958, 1654, 1109, 2056,  920,  813,  945,
#        1437,  602, 1482, 1054, 1126, 1176,  776,  567,  748,  950,  622,
#         346,  740, 1313,  500, 1491,  858,  585, 1442,  353,  664,  391,
#         637,  570,  673, 1140,  828, 1084, 1093, 1290,  566,  954, 1686,
#        1406, 1375,  416, 1351, 1831,  936,  513,  739, 1179,  889,  938,
#         846,  728,  792,  737,  627,  756, 1280,  583,  432, 1496, 1544,
#        1197,  468,  741,  812,  603,  873,  867,  708, 1048,  396,  369,
#         886,  621,  779, 1041,  318, 1007, 1162, 1130,  560, 1318, 1018,
#         669,  899,  613, 1296, 1418, 1700,  620,  609,  787, 1340, 1227,
#        1453, 1104,  907, 1690, 1145, 1481, 1456, 1263,  918, 1300,  636,
#        1942, 1013,  512,  890,  614, 1507,  559,  735,  478, 1556,  473,
#         573,  511,  658, 1236,  589,  781,  575,  738,  633,  584,  745,
#         601,  946, 1016,  538,  842,  705,  380, 1259,  839,  700, 2640,
#         645, 1652, 1368,  896,  286, 1036,  618,  832,  849,  882,  770,
#         632, 1233,  684,  349,  659,  617,  711,  623,  694,  419,  549,
#         922,  807,  888, 1228,  915, 1232,  944,  638, 1083, 1241, 1029,
#         919, 1033,  750,  444,  465, 2190,  785, 1103,  480,  661,  457,
#        1224,  760, 1277, 1244,  698,  934,  964,  877, 1814, 1199, 1181,
#         836,  461, 1454,  459,  801, 2333,  798,  686, 1320,  912,  929,
#         731,  525, 1148,  655, 2486,  965,  885,  474, 1229, 1343,  931,
#         900,  649, 1753, 1782, 1855,  399, 1609,  826,  541,  814,  734,
#        2020,  610,  630,  820,  940,  600,  150,  870,  660,  340,  580,
#         970,  470,  768,  656, 1742, 2240, 1021,  732,  952,  893,  757,
#         742,  606, 1118, 1235, 1439,  713, 1046, 1207, 1198,  977, 1750,
#         625,  811, 1210, 1963,  351,  906, 1553,  550, 1479,  428, 1250,
#        1044,  494, 1373, 1184, 1376, 1568, 1850,  663,  691,  860, 1353,
#         643,  563,  864,  504,  980,  403,  477,  675, 1470, 1190,  412,
#         806,  780,  880,  762,  994,  558,  407, 1450, 1970,  510, 1180,
#        1840, 1730,  769,  597, 1269, 1196,  389, 1635, 1146, 1102, 2347,
#         231, 1270, 1008,  379,  872,  857, 1317,  992, 1574, 1617, 1480,
#        2690, 1980, 1040,  876,  343,  294,  650,  564,  446,  916,  730,
#        3130,  487,  279,  397,  484,  305,  805,  450, 1026,  598,  657,
#         701, 2798,  218, 1252,  767,  840, 1240,  374,  536,  783, 1312,
#         802,  666,  471, 1030, 1838], dtype=int64)

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data['cd820'])
# Out:
# <Axes: >

# %%
data['cd80'][data['cd80'].argsort()[::-1]]
# Out:
# 480    4255
# 444    3190
# 515    3046
# 481    2840
# 356    2739
#        ...
# 256     337
# 506     333
# 516     324
# 488     225
# 3       221
# Name: cd80, Length: 532, dtype: int64

# %%
data = data.drop(index=data['cd80'][data['cd80'].argsort()[::-1]][0:1].index)

# %%
data = data.drop(columns=['zprior', 'drugs'],)

# %%
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#      censor  event  age     wtkg  hemo  homo  karnof  oprior  z30  preanti  \
# 0         0   1090   43   66.679     0     1     100       0    1     1352
# 1         1    794   31   73.030     0     1     100       0    1      930
# 2         0    957   41   66.226     0     1     100       0    1     1329
# 3         1    188   35   78.019     0     1     100       0    1      964
# 4         1    308   40   83.009     0     1     100       0    1      974
# ..      ...    ...  ...      ...   ...   ...     ...     ...  ...      ...
# 526       0   1097   24   71.000     1     0     100       0    1      334
# 527       1    154   21   52.300     1     0      90       0    1       24
# 528       1    588   16   63.000     1     0     100       0    1      753
# 529       0    395   17  102.967     1     0     100       0    1      417
# 530       1    465   14   60.000     1     0     100       0    0        0
#
#      ...  gender  str2  strat  symptom  cd40  cd420  cd496  r  cd80  cd820
# 0    ...       1     1      3        0   504    353    660  1   870    782
# 1    ...       1     1      3        0   244    225    106  1   708    699
# 2    ...       1     1      3        0   401    366    453  1   889    720
# 3    ...       1     1      3        0   221    132     -1  0   221    759
# 4    ...       1     1      3        1   150     90     20  1  1730   1160
# ..   ...     ...   ...    ...      ...   ...    ...    ... ..   ...    ...
# 526  ...       1     1      2        0   364    475    734  1   770    802
# 527  ...       1     1      2        0   415    181     84  1   949    666
# 528  ...       1     1      3        0   299    214    124  1   546    471
# 529  ...       1     1      3        0   373    218     -1  0  1759   1030
# 530  ...       1     0      1        0   166    169     28  1   999   1838
#
# [531 rows x 21 columns]

# %%
sns.displot(data['homo'])

# %%
Y = data['censor']
X = data.drop(columns=['censor'])

# %%
pca = PCA(n_components=2).fit(X)
X_PCA = pca.fit_transform(X)
X_EMM = pd.DataFrame(X_PCA, columns=['AXIS1','AXIS2'])
print(">>>> PCA Variance : {}".format(pca.explained_variance_ratio_))
# Out:
# >>>> PCA Variance : [0.44407949 0.27476111]

# %%
X_EMM
# Out:
#           AXIS1       AXIS2
# 0   -100.721601  954.147806
# 1   -309.658091  590.610418
# 2   -127.983872  948.063379
# 3   -601.597076  687.133792
# 4    760.864896  587.604545
# ..          ...         ...
# 526 -248.983252  -59.973003
# 527 -209.304782 -281.430423
# 528 -589.244854  450.718700
# 529  652.507945   28.091299
# 530  602.961911 -404.854183
#
# [531 rows x 2 columns]

# %%
minsize = [3, 5, 10, 15, 20, 30]
for m in minsize:
    print("min_cluster_size : {}".format(m))
    db = hdbscan.HDBSCAN(min_cluster_size=m).fit(X)
    palette = sns.color_palette()
    cluster_colors = [palette[col]
                    if col >= 0 else (0.5, 0.5, 0.5) for col in
                    db.labels_]
    plt.scatter(X.iloc[:,0], X.iloc[:,1], c=cluster_colors)
    plt.show()
# Out:
# min_cluster_size : 3
# min_cluster_size : 5
# min_cluster_size : 10
# min_cluster_size : 15
# min_cluster_size : 20
# min_cluster_size : 30

# %%
data
# Out:
#      censor  event  age     wtkg  hemo  homo  karnof  oprior  z30  preanti  \
# 0         0   1090   43   66.679     0     1     100       0    1     1352
# 1         1    794   31   73.030     0     1     100       0    1      930
# 2         0    957   41   66.226     0     1     100       0    1     1329
# 3         1    188   35   78.019     0     1     100       0    1      964
# 4         1    308   40   83.009     0     1     100       0    1      974
# ..      ...    ...  ...      ...   ...   ...     ...     ...  ...      ...
# 526       0   1097   24   71.000     1     0     100       0    1      334
# 527       1    154   21   52.300     1     0      90       0    1       24
# 528       1    588   16   63.000     1     0     100       0    1      753
# 529       0    395   17  102.967     1     0     100       0    1      417
# 530       1    465   14   60.000     1     0     100       0    0        0
#
#      ...  gender  str2  strat  symptom  cd40  cd420  cd496  r  cd80  cd820
# 0    ...       1     1      3        0   504    353    660  1   870    782
# 1    ...       1     1      3        0   244    225    106  1   708    699
# 2    ...       1     1      3        0   401    366    453  1   889    720
# 3    ...       1     1      3        0   221    132     -1  0   221    759
# 4    ...       1     1      3        1   150     90     20  1  1730   1160
# ..   ...     ...   ...    ...      ...   ...    ...    ... ..   ...    ...
# 526  ...       1     1      2        0   364    475    734  1   770    802
# 527  ...       1     1      2        0   415    181     84  1   949    666
# 528  ...       1     1      3        0   299    214    124  1   546    471
# 529  ...       1     1      3        0   373    218     -1  0  1759   1030
# 530  ...       1     0      1        0   166    169     28  1   999   1838
#
# [531 rows x 21 columns]

# %%
cm = confusion_matrix(data['censor'], db.labels_)
print(cm)
# Out:
# [[  0   0   0]
#  [351   0   0]
#  [180   0   0]]

# %%
print("TesT Acc : {}".format((cm[0,0] + cm[1,1])/cm.sum()))
print("F1-Score : {}".format(f1_score(data['censor'], db.labels_)))
# Out:
# TesT Acc : 0.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 print("TesT Acc : {}".format((cm[0,0] + cm[1,1])/cm.sum()))
# ----> 2 print("F1-Score : {}".format(f1_score(data['censor'], db.labels_)))
#
# File D:\win\Projects\test2\lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File D:\win\Projects\test2\lib\site-packages\sklearn\metrics\_classification.py:1238, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1070 @validate_params(
#    1071     {
#    1072         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1096     zero_division="warn",
#    1097 ):
#    1098     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1099
#    1100     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1236     array([0.66666667, 1.        , 0.66666667])
#    1237     """
# -> 1238     return fbeta_score(
#    1239         y_true,
#    1240         y_pred,
#    1241         beta=1,
#    1242         labels=labels,
#    1243         pos_label=pos_label,
#    1244         average=average,
#    1245         sample_weight=sample_weight,
#    1246         zero_division=zero_division,
#    1247     )
#
# File D:\win\Projects\test2\lib\site-packages\sklearn\utils\_param_validation.py:184, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     182 global_skip_validation = get_config()["skip_parameter_validation"]
#     183 if global_skip_validation:
# --> 184     return func(*args, **kwargs)
#     186 func_sig = signature(func)
#     188 # Map *args/**kwargs to the function signature
#
# File D:\win\Projects\test2\lib\site-packages\sklearn\metrics\_classification.py:1411, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1250 @validate_params(
#    1251     {
#    1252         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1278     zero_division="warn",
#    1279 ):
#    1280     """Compute the F-beta score.
#    1281
#    1282     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1408     0.38...
#    1409     """
# -> 1411     _, _, f, _ = precision_recall_fscore_support(
#    1412         y_true,
#    1413         y_pred,
#    1414         beta=beta,
#    1415         labels=labels,
#    1416         pos_label=pos_label,
#    1417         average=average,
#    1418         warn_for=("f-score",),
#    1419         sample_weight=sample_weight,
#    1420         zero_division=zero_division,
#    1421     )
#    1422     return f
#
# File D:\win\Projects\test2\lib\site-packages\sklearn\utils\_param_validation.py:184, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     182 global_skip_validation = get_config()["skip_parameter_validation"]
#     183 if global_skip_validation:
# --> 184     return func(*args, **kwargs)
#     186 func_sig = signature(func)
#     188 # Map *args/**kwargs to the function signature
#
# File D:\win\Projects\test2\lib\site-packages\sklearn\metrics\_classification.py:1721, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1563 """Compute precision, recall, F-measure and support for each class.
#    1564
#    1565 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1718  array([2, 2, 2]))
#    1719 """
#    1720 zero_division_value = _check_zero_division(zero_division)
# -> 1721 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1723 # Calculate tp_sum, pred_sum, true_sum ###
#    1724 samplewise = average == "samples"
#
# File D:\win\Projects\test2\lib\site-packages\sklearn\metrics\_classification.py:1516, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1514         if y_type == "multiclass":
#    1515             average_options.remove("samples")
# -> 1516         raise ValueError(
#    1517             "Target is %s but average='binary'. Please "
#    1518             "choose another average setting, one of %r." % (y_type, average_options)
#    1519         )
#    1520 elif pos_label not in (None, 1):
#    1521     warnings.warn(
#    1522         "Note that pos_label (set to %r) is ignored when "
#    1523         "average != 'binary' (got %r). You may use "
#    (...)
#    1526         UserWarning,
#    1527     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].

# %%
#plt 와 sns Setting
# %matplotlib inline
sns.set_context('poster')
sns.set_style('white')
sns.set_color_codes()
plot_kwds = {'alpha' : 0.5, 's' : 80, 'linewidths':0}
plt.rcParams["figure.figsize"] = [9,7]

# %%
num=100
moons, _ = data_maker.make_moons(n_samples=num, noise=0.01)
blobs, _ = data_maker.make_blobs(n_samples=num, centers=[(-0.75,2.25), (1.0, -2.0)], cluster_std=0.25)
blobs2, _ = data_maker.make_blobs(n_samples=num, centers=[(2,2.25), (-1, -2.0)], cluster_std=0.4)
test_data = np.vstack([moons, blobs,blobs2])
plt.scatter(test_data.T[0], test_data.T[1], color='b', **plot_kwds)
plt.show()

# %%
minsize = [3, 5, 10, 15, 20, 30]
for m in minsize:
    print("min_cluster_size : {}".format(m))
    db = hdbscan.HDBSCAN(min_cluster_size=m).fit(test_data)
    palette = sns.color_palette()
    cluster_colors = [palette[col]
                    if col >= 0 else (0.5, 0.5, 0.5) for col in
                    db.labels_]
    plt.scatter(test_data.T[0], test_data.T[1], c=cluster_colors, **plot_kwds)
    plt.show()
# Out:
# min_cluster_size : 3
# min_cluster_size : 5
# min_cluster_size : 10
# min_cluster_size : 15
# min_cluster_size : 20
# min_cluster_size : 30
